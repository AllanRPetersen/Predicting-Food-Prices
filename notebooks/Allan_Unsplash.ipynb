# %%
import requests

# %%
api_key = 'HbaYhOLNuzBDKvfs0qvVEB4Ymu1PxQmru9YdXvv2jfc'

# %%
# query = food
query = 'lettice'

# %%
response = requests.get(f'https://api.unsplash.com/search/photos?client_id={api_key}&query={query}')

# %%
response.url
# Out:
# 'https://api.unsplash.com/search/photos?client_id=HbaYhOLNuzBDKvfs0qvVEB4Ymu1PxQmru9YdXvv2jfc&query=carrots'

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'total': 1023,
#  'total_pages': 103,
#  'results': [{'id': 'fcgPRZmTM5w',
#    'created_at': '2018-03-27T16:57:35-04:00',
#    'updated_at': '2021-12-10T13:04:28-05:00',
#    'promoted_at': None,
#    'width': 5632,
#    'height': 3755,
#    'color': '#d9d9d9',
#    'blur_hash': 'LRL:_tRjJq?cHqJ8-=ROt,ODwKZ~',
#    'description': 'Fresh Vegetables Healthy Foods',
#    'alt_description': 'baby carrots',
#    'urls': {'raw': 'https://images.unsplash.com/photo-1522184216316-3c25379f9760?ixid=MnwyODIzMDd8MHwxfHNlYXJjaHwxfHxjYXJyb3RzfGVufDB8fHx8MTYzOTE4MjQ3NQ&ixlib=rb-1.2.1',
#     'full': 'https://images.unsplash.com/photo-1522184216316-3c25379f9760?crop=entropy&cs=srgb&fm=jpg&ixid=MnwyODIzMDd8MHwxfHNlYXJjaHwxfHxjYXJyb3RzfGVufDB8fHx8MTYzOTE4MjQ3NQ&ixlib=rb-1.2.1&q=85',
#     'regular': 'https://images.unsplash.com/photo-1522184216316-3c25379f9760?crop=entropy&cs=tinysrgb&fit=max&fm=jpg&ixid=MnwyODIzMDd8MHwxfHNlYXJjaHwxfHxjYXJyb3RzfGVufDB8fHx8MTYzOTE4MjQ3NQ&ixlib=rb-1.2.1&q=80&w=1080',
# ...

# %%
response.json()['results'][0]['urls']['small']
# Out:
# 'https://images.unsplash.com/photo-1522184216316-3c25379f9760?crop=entropy&cs=tinysrgb&fit=max&fm=jpg&ixid=MnwyODIzMDd8MHwxfHNlYXJjaHwxfHxjYXJyb3RzfGVufDB8fHx8MTYzOTE4MjQ3NQ&ixlib=rb-1.2.1&q=80&w=400'

# %%
#Title of picture

# %%
response.json()['results'][0]['alt_description']
# Out:
# 'baby carrots'

# %%
# User who took the picture

# %%
response.json()['results'][0]['user']['name']
# Out:
# 'Gabriel Gurrola'
