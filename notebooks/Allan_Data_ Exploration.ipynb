# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from pandas_profiling import ProfileReport

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Who eats the food we grow?
# Worldwide food\feed production and distribution, 1961-2013

# %%
food_use_df = pd.read_csv('../raw_data/Who_eats_the_food_we_grow/FAO.csv', encoding='latin-1')

# %%
food_use_df.head()
# Out:
#   Area Abbreviation  Area Code         Area  Item Code  \
# 0               AFG          2  Afghanistan       2511
# 1               AFG          2  Afghanistan       2805
# 2               AFG          2  Afghanistan       2513
# 3               AFG          2  Afghanistan       2513
# 4               AFG          2  Afghanistan       2514
#
#                        Item  Element Code Element         Unit  latitude  \
# 0        Wheat and products          5142    Food  1000 tonnes     33.94
# 1  Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
# 2       Barley and products          5521    Feed  1000 tonnes     33.94
# 3       Barley and products          5142    Food  1000 tonnes     33.94
# 4        Maize and products          5521    Feed  1000 tonnes     33.94
#
#    longitude   Y1961   Y1962   Y1963   Y1964   Y1965   Y1966   Y1967   Y1968  \
# 0      67.71  1928.0  1904.0  1666.0  1950.0  2001.0  1808.0  2053.0  2045.0
# ...

# %%
food_use_df.shape
# Out:
# (21477, 63)

# %%
food_use_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21477 entries, 0 to 21476
# Data columns (total 63 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Area Abbreviation  21477 non-null  object
#  1   Area Code          21477 non-null  int64
#  2   Area               21477 non-null  object
#  3   Item Code          21477 non-null  int64
#  4   Item               21477 non-null  object
#  5   Element Code       21477 non-null  int64
#  6   Element            21477 non-null  object
#  7   Unit               21477 non-null  object
#  8   latitude           21477 non-null  float64
#  9   longitude          21477 non-null  float64
#  10  Y1961              17938 non-null  float64
#  11  Y1962              17938 non-null  float64
#  12  Y1963              17938 non-null  float64
#  13  Y1964              17938 non-null  float64
#  14  Y1965              17938 non-null  float64
#  15  Y1966              17938 non-null  float64
# ...

# %%
food_use_df.duplicated().sum()
# Out:
# 0

# %%
food_use_df.isnull().sum().sort_values(ascending=False)/len(food_use_df)
# Out:
# Y1982           0.164781
# Y1980           0.164781
# Y1972           0.164781
# Y1973           0.164781
# Y1974           0.164781
#                   ...
# Element Code    0.000000
# Item            0.000000
# Item Code       0.000000
# Area            0.000000
# Y2013           0.000000
# Length: 63, dtype: float64

# %%
#profile = ProfileReport(food_use_df)
#profile

# %% [markdown]
# ## Crop Yield Prediction Dataset
# Predicting crop yield of 10 most consumed crops in world

# %%
crop_yield_pred_df1 = pd.read_csv('../raw_data/Crop Yield Prediction Dataset/yield.csv')

# %%
crop_yield_pred_df1.head()
# Out:
#   Domain Code Domain  Area Code         Area  Element Code Element  Item Code  \
# 0          QC  Crops          2  Afghanistan          5419   Yield         56
# 1          QC  Crops          2  Afghanistan          5419   Yield         56
# 2          QC  Crops          2  Afghanistan          5419   Yield         56
# 3          QC  Crops          2  Afghanistan          5419   Yield         56
# 4          QC  Crops          2  Afghanistan          5419   Yield         56
#
#     Item  Year Code  Year   Unit  Value
# 0  Maize       1961  1961  hg/ha  14000
# 1  Maize       1962  1962  hg/ha  14000
# 2  Maize       1963  1963  hg/ha  14260
# 3  Maize       1964  1964  hg/ha  14257
# 4  Maize       1965  1965  hg/ha  14400

# %%
crop_yield_pred_df1.shape
# Out:
# (56717, 12)

# %%
crop_yield_pred_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56717 entries, 0 to 56716
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Domain Code   56717 non-null  object
#  1   Domain        56717 non-null  object
#  2   Area Code     56717 non-null  int64
#  3   Area          56717 non-null  object
#  4   Element Code  56717 non-null  int64
#  5   Element       56717 non-null  object
#  6   Item Code     56717 non-null  int64
#  7   Item          56717 non-null  object
#  8   Year Code     56717 non-null  int64
#  9   Year          56717 non-null  int64
#  10  Unit          56717 non-null  object
#  11  Value         56717 non-null  int64
# dtypes: int64(6), object(6)
# memory usage: 5.2+ MB

# %%
crop_yield_pred_df1.duplicated().sum()
# Out:
# 0

# %%
crop_yield_pred_df1.isnull().sum().sort_values(ascending=False)/len(crop_yield_pred_df1)
# Out:
# Domain Code     0.0
# Domain          0.0
# Area Code       0.0
# Area            0.0
# Element Code    0.0
# Element         0.0
# Item Code       0.0
# Item            0.0
# Year Code       0.0
# Year            0.0
# Unit            0.0
# Value           0.0
# dtype: float64

# %%
crop_yield_pred_df2 = pd.read_csv('../raw_data/Crop Yield Prediction Dataset/yield_df.csv')

# %%
crop_yield_pred_df2.head()
# Out:
#    Unnamed: 0     Area         Item  Year  hg/ha_yield  \
# 0           0  Albania        Maize  1990        36613
# 1           1  Albania     Potatoes  1990        66667
# 2           2  Albania  Rice, paddy  1990        23333
# 3           3  Albania      Sorghum  1990        12500
# 4           4  Albania     Soybeans  1990         7000
#
#    average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                         1485.0              121.0     16.37
# 1                         1485.0              121.0     16.37
# 2                         1485.0              121.0     16.37
# 3                         1485.0              121.0     16.37
# 4                         1485.0              121.0     16.37

# %%
crop_yield_pred_df2.shape
# Out:
# (28242, 8)

# %%
crop_yield_pred_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28242 entries, 0 to 28241
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     28242 non-null  int64
#  1   Area                           28242 non-null  object
#  2   Item                           28242 non-null  object
#  3   Year                           28242 non-null  int64
#  4   hg/ha_yield                    28242 non-null  int64
#  5   average_rain_fall_mm_per_year  28242 non-null  float64
#  6   pesticides_tonnes              28242 non-null  float64
#  7   avg_temp                       28242 non-null  float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 1.7+ MB

# %%
crop_yield_pred_df2.duplicated().sum()
# Out:
# 0

# %%
crop_yield_pred_df2.isnull().sum().sort_values(ascending=False)/len(crop_yield_pred_df2)
# Out:
# Unnamed: 0                       0.0
# Area                             0.0
# Item                             0.0
# Year                             0.0
# hg/ha_yield                      0.0
# average_rain_fall_mm_per_year    0.0
# pesticides_tonnes                0.0
# avg_temp                         0.0
# dtype: float64

# %% [markdown]
# ## Global Food & Agriculture Statistics
# Land use and farming inputs

# %%
global_food_agri_df_crops = pd.read_csv('../raw_data/Global Food and Agriculture Statistics/fao_data_crops_data.csv')

# %%
global_food_agri_df_crops.head()
# Out:
#   country_or_area element_code         element    year unit    value  \
# 0      Americas +           31  Area Harvested  2007.0   Ha  49404.0
# 1      Americas +           31  Area Harvested  2006.0   Ha  49404.0
# 2      Americas +           31  Area Harvested  2005.0   Ha  49404.0
# 3      Americas +           31  Area Harvested  2004.0   Ha  49113.0
# 4      Americas +           31  Area Harvested  2003.0   Ha  48559.0
#
#   value_footnotes          category
# 0              A   agave_fibres_nes
# 1              A   agave_fibres_nes
# 2              A   agave_fibres_nes
# 3              A   agave_fibres_nes
# 4              A   agave_fibres_nes

# %%
global_food_agri_df_crops.shape
# Out:
# (2255349, 8)

# %%
global_food_agri_df_crops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2255349 entries, 0 to 2255348
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   country_or_area  object
#  1   element_code     object
#  2   element          object
#  3   year             float64
#  4   unit             object
#  5   value            float64
#  6   value_footnotes  object
#  7   category         object
# dtypes: float64(2), object(6)
# memory usage: 137.7+ MB

# %%
global_food_agri_df_crops.duplicated().sum()
# Out:
# 0

# %%
global_food_agri_df_crops.isnull().sum().sort_values(ascending=False)/len(global_food_agri_df_crops)
# Out:
# value_footnotes    0.212553
# element            0.000427
# year               0.000427
# unit               0.000427
# value              0.000427
# country_or_area    0.000000
# element_code       0.000000
# category           0.000000
# dtype: float64

# %%
global_food_agri_df_fertilizers = pd.read_csv('../raw_data/Global Food and Agriculture Statistics/fao_data_fertilizers_data.csv')

# %%
global_food_agri_df_fertilizers.head()
# Out:
#   country_or_area element_code element    year  unit   value value_footnotes  \
# 0      Americas +           11  Stocks  2007.0  Head  3100.0              A
# 1      Americas +           11  Stocks  2006.0  Head  3100.0              A
# 2      Americas +           11  Stocks  2005.0  Head  3100.0              A
# 3      Americas +           11  Stocks  2004.0  Head  3100.0              A
# 4      Americas +           11  Stocks  2003.0  Head  3100.0              A
#
#            category
# 0  animals_live_nes
# 1  animals_live_nes
# 2  animals_live_nes
# 3  animals_live_nes
# 4  animals_live_nes

# %%
global_food_agri_df_fertilizers.shape
# Out:
# (102204, 8)

# %%
global_food_agri_df_fertilizers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102204 entries, 0 to 102203
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   country_or_area  102204 non-null  object
#  1   element_code     102204 non-null  object
#  2   element          102124 non-null  object
#  3   year             102124 non-null  float64
#  4   unit             102124 non-null  object
#  5   value            102124 non-null  float64
#  6   value_footnotes  57582 non-null   object
#  7   category         102204 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 6.2+ MB

# %%
global_food_agri_df_fertilizers.duplicated().sum()
# Out:
# 0

# %%
global_food_agri_df_fertilizers.isnull().sum().sort_values(ascending=False)/len(global_food_agri_df_fertilizers)
# Out:
# value_footnotes    0.436597
# element            0.000783
# year               0.000783
# unit               0.000783
# value              0.000783
# country_or_area    0.000000
# element_code       0.000000
# category           0.000000
# dtype: float64

# %%
global_food_agri_df_forest = pd.read_csv('../raw_data/Global Food and Agriculture Statistics/fao_data_forest_data.csv')

# %%
global_food_agri_df_forest.head()
# Out:
#   country_or_area element_code             element    year    unit  value  \
# 0         Albania          150  Non-fertilizer use  2007.0  tonnes    0.0
# 1         Albania          150  Non-fertilizer use  2006.0  tonnes    0.0
# 2         Albania          150  Non-fertilizer use  2005.0  tonnes    0.0
# 3         Albania          150  Non-fertilizer use  2004.0  tonnes    0.0
# 4         Albania          150  Non-fertilizer use  2003.0  tonnes    0.0
#
#   value_footnotes           category
# 0              NR  ammonia_anhydrous
# 1              NR  ammonia_anhydrous
# 2              NR  ammonia_anhydrous
# 3              NR  ammonia_anhydrous
# 4              NR  ammonia_anhydrous

# %%
global_food_agri_df_forest.shape
# Out:
# (1365148, 8)

# %%
global_food_agri_df_forest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1365148 entries, 0 to 1365147
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   country_or_area  1365148 non-null  object
#  1   element_code     1365148 non-null  object
#  2   element          1364725 non-null  object
#  3   year             1364725 non-null  float64
#  4   unit             1364725 non-null  object
#  5   value            1364725 non-null  float64
#  6   value_footnotes  967174 non-null   object
#  7   category         1365148 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 83.3+ MB

# %%
global_food_agri_df_forest.duplicated().sum()
# Out:
# 0

# %%
global_food_agri_df_forest.isnull().sum().sort_values(ascending=False)/len(global_food_agri_df_forest)
# Out:
# value_footnotes    0.291524
# element            0.000310
# year               0.000310
# unit               0.000310
# value              0.000310
# country_or_area    0.000000
# element_code       0.000000
# category           0.000000
# dtype: float64

# %%
global_food_agri_df_land = pd.read_csv('../raw_data/Global Food and Agriculture Statistics/fao_data_land_data.csv')

# %%
global_food_agri_df_land.head()
# Out:
#   country_or_area element_code element    year     unit    value  \
# 0     Afghanistan           11    Area  2007.0  1000 Ha  38661.0
# 1     Afghanistan           11    Area  2006.0  1000 Ha  38659.0
# 2     Afghanistan           11    Area  2005.0  1000 Ha  38515.0
# 3     Afghanistan           11    Area  2004.0  1000 Ha  38064.0
# 4     Afghanistan           11    Area  2003.0  1000 Ha  38899.0
#
#   value_footnotes           category
# 0              Q   agricultural_area
# 1              Fm  agricultural_area
# 2              Fm  agricultural_area
# 3              Fm  agricultural_area
# 4              Fm  agricultural_area

# %%
global_food_agri_df_land.shape
# Out:
# (104784, 8)

# %%
global_food_agri_df_land.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104784 entries, 0 to 104783
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   country_or_area  104784 non-null  object
#  1   element_code     104784 non-null  object
#  2   element          104659 non-null  object
#  3   year             104659 non-null  float64
#  4   unit             104659 non-null  object
#  5   value            104659 non-null  float64
#  6   value_footnotes  104658 non-null  object
#  7   category         104784 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 6.4+ MB

# %%
global_food_agri_df_land.duplicated().sum()
# Out:
# 0

# %%
global_food_agri_df_land.isnull().sum().sort_values(ascending=False)/len(global_food_agri_df_land)
# Out:
# value_footnotes    0.001202
# element            0.001193
# year               0.001193
# unit               0.001193
# value              0.001193
# country_or_area    0.000000
# element_code       0.000000
# category           0.000000
# dtype: float64

# %%
global_food_agri_df_prod_indices = pd.read_csv('../raw_data/Global Food and Agriculture Statistics/fao_data_production_indices_data.csv')

# %%
global_food_agri_df_prod_indices.head()
# Out:
#   country_or_area element_code                               element    year  \
# 0     Afghanistan          152  Gross Production 1999-2001 (1000 I$)  2007.0
# 1     Afghanistan          152  Gross Production 1999-2001 (1000 I$)  2006.0
# 2     Afghanistan          152  Gross Production 1999-2001 (1000 I$)  2005.0
# 3     Afghanistan          152  Gross Production 1999-2001 (1000 I$)  2004.0
# 4     Afghanistan          152  Gross Production 1999-2001 (1000 I$)  2003.0
#
#           unit      value value_footnotes         category
# 0  1000 Int. $  2486910.0              A   agriculture_pin
# 1  1000 Int. $  2278516.0              A   agriculture_pin
# 2  1000 Int. $  2524097.0              A   agriculture_pin
# 3  1000 Int. $  2226346.0              A   agriculture_pin
# 4  1000 Int. $  2289434.0              A   agriculture_pin

# %%
global_food_agri_df_prod_indices.shape
# Out:
# (311634, 8)

# %%
global_food_agri_df_prod_indices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311634 entries, 0 to 311633
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   country_or_area  311634 non-null  object
#  1   element_code     311634 non-null  object
#  2   element          311624 non-null  object
#  3   year             311624 non-null  float64
#  4   unit             311624 non-null  object
#  5   value            311624 non-null  float64
#  6   value_footnotes  311624 non-null  object
#  7   category         311634 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 19.0+ MB

# %%
global_food_agri_df_prod_indices.duplicated().sum()
# Out:
# 0

# %%
global_food_agri_df_prod_indices.isnull().sum().sort_values(ascending=False)/len(global_food_agri_df_prod_indices)
# Out:
# element            0.000032
# year               0.000032
# unit               0.000032
# value              0.000032
# value_footnotes    0.000032
# country_or_area    0.000000
# element_code       0.000000
# category           0.000000
# dtype: float64

# %% [markdown]
# ## Worldwide Meat Consumption
# Worldwide consumption of different meats by country from 1991

# %%
meat_consump_df = pd.read_csv('../raw_data/Worldwide Meat Consumption/meat_consumption_worldwide.csv')

# %%
meat_consump_df.head()
# Out:
#   LOCATION SUBJECT MEASURE  TIME      Value
# 0      AUS    BEEF  KG_CAP  1991  27.721815
# 1      AUS    BEEF  KG_CAP  1992  26.199591
# 2      AUS    BEEF  KG_CAP  1993  26.169094
# 3      AUS    BEEF  KG_CAP  1994  25.456134
# 4      AUS    BEEF  KG_CAP  1995  25.340226

# %%
meat_consump_df.shape
# Out:
# (13760, 5)

# %%
meat_consump_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13760 entries, 0 to 13759
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LOCATION  13760 non-null  object
#  1   SUBJECT   13760 non-null  object
#  2   MEASURE   13760 non-null  object
#  3   TIME      13760 non-null  int64
#  4   Value     13760 non-null  float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 537.6+ KB

# %%
meat_consump_df.duplicated().sum()
# Out:
# 0

# %%
meat_consump_df.isnull().sum().sort_values(ascending=False)/len(meat_consump_df)
# Out:
# LOCATION    0.0
# SUBJECT     0.0
# MEASURE     0.0
# TIME        0.0
# Value       0.0
# dtype: float64

# %% [markdown]
# # Prices

# %% [markdown]
# ## Global Food Prices
# 743k Rows of Monthly Market Food Prices Across Developing Countries

# %%
global_food_prices_df = pd.read_csv('../raw_data/Global Food Prices/wfp_market_food_prices.csv', encoding='latin-1')

# %%
global_food_prices_df.head()
# Out:
#    adm0_id    adm0_name  adm1_id   adm1_name  mkt_id  mkt_name  cm_id cm_name  \
# 0        1  Afghanistan      272  Badakhshan     266  Fayzabad     55   Bread
# 1        1  Afghanistan      272  Badakhshan     266  Fayzabad     55   Bread
# 2        1  Afghanistan      272  Badakhshan     266  Fayzabad     55   Bread
# 3        1  Afghanistan      272  Badakhshan     266  Fayzabad     55   Bread
# 4        1  Afghanistan      272  Badakhshan     266  Fayzabad     55   Bread
#
#    cur_id cur_name  pt_id pt_name  um_id um_name  mp_month  mp_year  mp_price  \
# 0      87      AFN     15  Retail      5      KG         1     2014      50.0
# 1      87      AFN     15  Retail      5      KG         2     2014      50.0
# 2      87      AFN     15  Retail      5      KG         3     2014      50.0
# 3      87      AFN     15  Retail      5      KG         4     2014      50.0
# 4      87      AFN     15  Retail      5      KG         5     2014      50.0
#
#   mp_commoditysource
# ...

# %%
global_food_prices_df.shape
# Out:
# (743914, 18)

# %%
global_food_prices_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 743914 entries, 0 to 743913
# Data columns (total 18 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   adm0_id             743914 non-null  int64
#  1   adm0_name           743914 non-null  object
#  2   adm1_id             743914 non-null  int64
#  3   adm1_name           729965 non-null  object
#  4   mkt_id              743914 non-null  int64
#  5   mkt_name            743914 non-null  object
#  6   cm_id               743914 non-null  int64
#  7   cm_name             743914 non-null  object
#  8   cur_id              743914 non-null  int64
#  9   cur_name            743914 non-null  object
#  10  pt_id               743914 non-null  int64
#  11  pt_name             743914 non-null  object
#  12  um_id               743914 non-null  int64
#  13  um_name             743914 non-null  object
#  14  mp_month            743914 non-null  int64
# ...

# %%
global_food_prices_df.duplicated().sum()
# Out:
# 0

# %%
global_food_prices_df.isnull().sum().sort_values(ascending=False)/len(global_food_prices_df)
# Out:
# adm1_name             0.018751
# adm0_id               0.000000
# pt_id                 0.000000
# mp_price              0.000000
# mp_year               0.000000
# mp_month              0.000000
# um_name               0.000000
# um_id                 0.000000
# pt_name               0.000000
# cur_name              0.000000
# adm0_name             0.000000
# cur_id                0.000000
# cm_name               0.000000
# cm_id                 0.000000
# mkt_name              0.000000
# mkt_id                0.000000
# adm1_id               0.000000
# mp_commoditysource    0.000000
# dtype: float64

# %% [markdown]
# ## Global Food Prices Database
# Updated Global Market Food Prices with 1.048M rows

# %%
global_food_prices_database_df = pd.read_csv('../raw_data/Global Food Prices Database/wfp_food_prices_database.csv')
# Out:
# /Users/plyck/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
global_food_prices_database_df.tail()
# Out:
#          adm0_id adm0_name  adm1_id adm1_name  mkt_id mkt_name  cm_id  \
# 1560546    271.0  Zimbabwe     3444  Midlands    2185   Vhugwi    497
# 1560547    271.0  Zimbabwe     3444  Midlands    2187   Murowa     50
# 1560548    271.0  Zimbabwe     3444  Midlands    2187   Murowa     51
# 1560549    271.0  Zimbabwe     3444  Midlands    2187   Murowa     96
# 1560550    271.0  Zimbabwe     3444  Midlands    2187   Murowa    264
#
#                                      cm_name  cur_id cur_name  pt_id pt_name  \
# 1560546    Sugar (white, fortified) - Retail     0.0      USD     15  Retail
# 1560547                       Beans - Retail     0.0      USD     15  Retail
# 1560548                       Maize - Retail     0.0      USD     15  Retail
# 1560549             Oil (vegetable) - Retail     0.0      USD     15  Retail
# 1560550  Maize meal (white, roller) - Retail     0.0      USD     15  Retail
#
#          um_id um_name  mp_month  mp_year  mp_price  mp_commoditysource
# ...

# %%
global_food_prices_database_df['cm_name'].unique()
# Out:
# array(['Bread - Retail', 'Wheat - Retail', 'Rice (low quality) - Retail',
#        'Wage (qualified labour) - Retail',
#        'Livestock (sheep, one-year-old alive female) - Retail',
#        'Fuel (diesel) - Retail', 'Exchange rate - Retail',
#        'Wage (non-qualified labour, non-agricultural) - Retail',
#        'Oil (cooking) - Retail', 'Sugar - Retail', 'Pulses - Retail',
#        'Wheat flour (high quality) - Retail', 'Salt - Retail',
#        'Rice (high quality) - Retail',
#        'Wheat flour (low quality) - Retail', 'Wheat flour - Retail',
#        'Rice - Retail', 'Beans (white) - Retail', 'Milk - Retail',
#        'Potatoes - Retail', 'Eggs - Retail', 'Meat (chicken) - Retail',
#        'Lentils - Retail', 'Pasta - Retail', 'Tomatoes - Retail',
#        'Oil - Retail', 'Meat (beef) - Retail', 'Cheese (dry) - Retail',
#        'Carrots - Retail', 'Onions - Retail', 'Bananas - Retail',
#        'Tea - Retail', 'Fuel (petrol-gasoline) - Retail',
# ...

# %%
global_food_prices_database_df['mp_year'].nunique()
# Out:
# 31

# %%
food_price_2020 = global_food_prices_database_df[global_food_prices_database_df['mp_year'] == 2020]

# %%
food_price_2020['cur_name'].unique()
# Out:
# array(['AFN', 'AOA', 'ARS', 'AMD', 'BDT', 'INR', 'BYR', 'XOF', 'BTN',
#        'BOB', 'BIF', 'KHR', 'XAF', 'CVE', 'CNY', 'COP', 'CDF', 'DJF',
#        'DOP', 'USD', 'EGP', 'ETB', 'GMD', 'GHS', 'GTQ', 'GNF', 'HTG',
#        'HNL', 'IDR', 'IRR', 'IQD', 'JPY', 'JOD', 'KZT', 'KES', 'KGS',
#        'LAK', 'LBP', 'LSL', 'LRD', 'LYD', 'MWK', 'SOS', 'MRO', 'MXN',
#        'MNT', 'MZN', 'MMK', 'NAD', 'NPR', 'NIO', 'NGN', 'PKR', 'PAB',
#        'PYG', 'PEN', 'PHP', 'RUB', 'RWF', 'SLL', 'ZAR', 'SSP', 'LKR',
#        'NIS', 'SDG', 'SZL', 'SYP', 'TJS', 'THB', 'TRY', 'UGX', 'TZS',
#        'YER', 'ZMW'], dtype=object)

# %%
food_price_2020[food_price_2020['mp_month'] == 7].shape
# Out:
# (22408, 18)

# %%
food_price_2020.groupby(['adm0_name', 'cm_name']).count()
# Out:
#                                                     adm0_id  adm1_id  \
# adm0_name   cm_name
# Afghanistan Bread - Retail                              168      168
#             Exchange rate - Retail                      168      168
#             Fuel (diesel) - Retail                      168      168
#             Oil (cooking) - Retail                      136      136
#             Pulses - Retail                             136      136
# ...                                                     ...      ...
# Zambia      Groundnuts (shelled) - Retail               395      395
#             Maize (white) - Retail                      376      376
#             Maize meal (white, breakfast) - Retail      418      418
#             Maize meal (white, roller) - Retail         298      298
#             Rice (local) - Retail                       341      341
#
#                                                     adm1_name  mkt_id  \
# adm0_name   cm_name
# ...

# %%
food_price_2020.groupby(['adm0_name', 'cm_name']).head()
# Out:
#          adm0_id    adm0_name  adm1_id   adm1_name  mkt_id  mkt_name  cm_id  \
# 69           1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 70           1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 71           1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 72           1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 275          1.0  Afghanistan      272  Badakhshan     266  Fayzabad     84
# ...          ...          ...      ...         ...     ...       ...    ...
# 1518003    270.0       Zambia     3426     Central     392    Mkushi    265
# 1518004    270.0       Zambia     3426     Central     392    Mkushi    265
# 1518005    270.0       Zambia     3426     Central     392    Mkushi    265
# 1518006    270.0       Zambia     3426     Central     392    Mkushi    265
# 1518007    270.0       Zambia     3426     Central     392    Mkushi    265
#
# ...

# %%
global_food_prices_database_df[global_food_prices_database_df['cur_name'] == 'USD'].shape
# Out:
# (22416, 18)

# %%
 global_food_prices_database_df.groupby('mp_year').count()
# Out:
#          adm0_id  adm0_name  adm1_id  adm1_name  mkt_id  mkt_name   cm_id  \
# mp_year
# 1990         140        140      140        140     140       140     140
# 1991         134        134      134        134     134       134     134
# 1992         280        280      280        276     280       280     280
# 1993         284        284      284        270     284       284     284
# 1994        1537       1537     1537        943    1537      1537    1537
# 1995        1287       1287     1287       1035    1287      1287    1287
# 1996        2022       2022     2022       1146    2022      2022    2022
# 1997        1638       1638     1638       1172    1638      1638    1638
# 1998        1792       1792     1792       1321    1792      1792    1792
# 1999        1713       1713     1713       1271    1713      1713    1713
# 2000        3750       3750     3750       2484    3750      3750    3750
# ...

# %%
global_food_prices_database_df.shape
# Out:
# (1560551, 18)

# %%
global_food_prices_database_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560551 entries, 0 to 1560550
# Data columns (total 18 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   adm0_id             1560551 non-null  float64
#  1   adm0_name           1560551 non-null  object
#  2   adm1_id             1560551 non-null  int64
#  3   adm1_name           1089223 non-null  object
#  4   mkt_id              1560551 non-null  int64
#  5   mkt_name            1560551 non-null  object
#  6   cm_id               1560551 non-null  int64
#  7   cm_name             1560551 non-null  object
#  8   cur_id              1560551 non-null  float64
#  9   cur_name            1560551 non-null  object
#  10  pt_id               1560551 non-null  int64
#  11  pt_name             1560551 non-null  object
#  12  um_id               1560551 non-null  int64
#  13  um_name             1560551 non-null  object
#  14  mp_month            1560551 non-null  int64
# ...

# %%
global_food_prices_database_df.duplicated().sum()
# Out:
# 0

# %%
global_food_prices_database_df.isnull().sum().sort_values(ascending=False)/len(global_food_prices_database_df)
# Out:
# mp_commoditysource    1.000000
# adm1_name             0.302027
# pt_id                 0.000000
# mp_price              0.000000
# mp_year               0.000000
# mp_month              0.000000
# um_name               0.000000
# um_id                 0.000000
# pt_name               0.000000
# adm0_id               0.000000
# adm0_name             0.000000
# cur_id                0.000000
# cm_name               0.000000
# cm_id                 0.000000
# mkt_name              0.000000
# mkt_id                0.000000
# adm1_id               0.000000
# cur_name              0.000000
# dtype: float64

# %% [markdown]
# ## Global Food Prices Database (Cleaned)
# Updated Global Market Food Prices with 1.048M rows

# %%
price_df = pd.read_csv('../raw_data/Global Food Prices Database/wfp_food_prices_database.csv')
# Out:
# /Users/plyck/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
price_df.head()
# Out:
#    adm0_id    adm0_name  adm1_id   adm1_name  mkt_id  mkt_name  cm_id  \
# 0      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 1      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 2      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 3      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 4      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
#
#           cm_name  cur_id cur_name  pt_id pt_name  um_id um_name  mp_month  \
# 0  Bread - Retail     0.0      AFN     15  Retail      5      KG         1
# 1  Bread - Retail     0.0      AFN     15  Retail      5      KG         2
# 2  Bread - Retail     0.0      AFN     15  Retail      5      KG         3
# 3  Bread - Retail     0.0      AFN     15  Retail      5      KG         4
# 4  Bread - Retail     0.0      AFN     15  Retail      5      KG         5
#
#    mp_year  mp_price  mp_commoditysource
# 0     2014      50.0                 NaN
# ...

# %%
price_df.isnull().sum()/len(price_df)
# Out:
# adm0_id               0.000000
# adm0_name             0.000000
# adm1_id               0.000000
# adm1_name             0.302027
# mkt_id                0.000000
# mkt_name              0.000000
# cm_id                 0.000000
# cm_name               0.000000
# cur_id                0.000000
# cur_name              0.000000
# pt_id                 0.000000
# pt_name               0.000000
# um_id                 0.000000
# um_name               0.000000
# mp_month              0.000000
# mp_year               0.000000
# mp_price              0.000000
# mp_commoditysource    1.000000
# dtype: float64

# %%
#dropping the mp_commoditysource because it's 100% Nan's

price_df.drop(columns='mp_commoditysource', inplace=True)

# %%
price_df['adm1_name'].nunique()
# Out:
# 613

# %%
price_df['adm1_name'].fillna("Unknown", inplace=True)

# %%
price_df['adm1_name'].nunique()
# Out:
# 614

# %%
price_df.isnull().sum()/len(price_df)
# Out:
# adm0_id      0.0
# adm0_name    0.0
# adm1_id      0.0
# adm1_name    0.0
# mkt_id       0.0
# mkt_name     0.0
# cm_id        0.0
# cm_name      0.0
# cur_id       0.0
# cur_name     0.0
# pt_id        0.0
# pt_name      0.0
# um_id        0.0
# um_name      0.0
# mp_month     0.0
# mp_year      0.0
# mp_price     0.0
# dtype: float64

# %%
price_df['cm_name'] = price_df['cm_name'].apply(lambda x: x.split(' ')[0])

# %%
price_df.head()
# Out:
#    adm0_id    adm0_name  adm1_id   adm1_name  mkt_id  mkt_name  cm_id cm_name  \
# 0      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55   Bread
# 1      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55   Bread
# 2      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55   Bread
# 3      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55   Bread
# 4      1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55   Bread
#
#    cur_id cur_name  pt_id pt_name  um_id um_name  mp_month  mp_year  mp_price
# 0     0.0      AFN     15  Retail      5      KG         1     2014      50.0
# 1     0.0      AFN     15  Retail      5      KG         2     2014      50.0
# 2     0.0      AFN     15  Retail      5      KG         3     2014      50.0
# 3     0.0      AFN     15  Retail      5      KG         4     2014      50.0
# 4     0.0      AFN     15  Retail      5      KG         5     2014      50.0

# %%
price_2020_df = price_df[price_df['mp_year'] == 2020]

# %%
price_2020_df.shape
# Out:
# (165098, 17)

# %%
price_2020_df['cur_name'].unique()
# Out:
# array(['AFN', 'AOA', 'ARS', 'AMD', 'BDT', 'INR', 'BYR', 'XOF', 'BTN',
#        'BOB', 'BIF', 'KHR', 'XAF', 'CVE', 'CNY', 'COP', 'CDF', 'DJF',
#        'DOP', 'USD', 'EGP', 'ETB', 'GMD', 'GHS', 'GTQ', 'GNF', 'HTG',
#        'HNL', 'IDR', 'IRR', 'IQD', 'JPY', 'JOD', 'KZT', 'KES', 'KGS',
#        'LAK', 'LBP', 'LSL', 'LRD', 'LYD', 'MWK', 'SOS', 'MRO', 'MXN',
#        'MNT', 'MZN', 'MMK', 'NAD', 'NPR', 'NIO', 'NGN', 'PKR', 'PAB',
#        'PYG', 'PEN', 'PHP', 'RUB', 'RWF', 'SLL', 'ZAR', 'SSP', 'LKR',
#        'NIS', 'SDG', 'SZL', 'SYP', 'TJS', 'THB', 'TRY', 'UGX', 'TZS',
#        'YER', 'ZMW'], dtype=object)

# %%
# Source Wiki: It was previously known as the new Israeli shekel and the non-official abbreviation of NIS.
# Need to change NIS to ILS (Israeli New Shekel)

# %%
price_2020_df['cur_name'] = price_2020_df['cur_name'].apply(lambda x: x.replace('NIS','ILS'))
# Out:
# /var/folders/ld/8g4lbtw14x12q9rxlrk7ccx00000gn/T/ipykernel_4208/2113586509.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_2020_df['cur_name'] = price_2020_df['cur_name'].apply(lambda x: x.replace('NIS','ILS'))

# %%
currencies = price_2020_df['cur_name'].unique()

# %%
type(currencies)
# Out:
# numpy.ndarray

# %%
currencies = currencies.tolist()

# %%
currencies.sort()

# %%
len(currencies)
# Out:
# 74

# %%
#SSP = South Sudanese pound
# This is not in our currency exchange API so must be removed and added later.

# %%
currencies.remove("SSP")

# %%
len(currencies)
# Out:
# 73

# %%
#API call to get the conversion rates in the list currencies

# %%
import requests

# %%
api_key = 'e3479b3ac491d8699be3a12b7cf7e51d'

# %%
curr = ','.join(currencies)

# %%
response = requests.get(f'http://api.currencylayer.com/live?access_key={api_key}&currencies={curr}&format=1')

# %%
response.url
# Out:
# 'http://api.currencylayer.com/live?access_key=e3479b3ac491d8699be3a12b7cf7e51d&currencies=AFN,AMD,AOA,ARS,BDT,BIF,BOB,BTN,BYR,CDF,CNY,COP,CVE,DJF,DOP,EGP,ETB,GHS,GMD,GNF,GTQ,HNL,HTG,IDR,ILS,INR,IQD,IRR,JOD,JPY,KES,KGS,KHR,KZT,LAK,LBP,LKR,LRD,LSL,LYD,MMK,MNT,MRO,MWK,MXN,MZN,NAD,NGN,NIO,NPR,PAB,PEN,PHP,PKR,PYG,RUB,RWF,SDG,SLL,SOS,SYP,SZL,THB,TJS,TRY,TZS,UGX,USD,XAF,XOF,YER,ZAR,ZMW&format=1'

# %%
response.json()
# Out:
# {'success': True,
#  'terms': 'https://currencylayer.com/terms',
#  'privacy': 'https://currencylayer.com/privacy',
#  'timestamp': 1638864604,
#  'source': 'USD',
#  'quotes': {'USDAFN': 96.170039,
#   'USDAMD': 491.708104,
#   'USDAOA': 564.209024,
#   'USDARS': 101.2478,
#   'USDBDT': 85.872927,
#   'USDBIF': 1994.3451,
#   'USDBOB': 6.911326,
#   'USDBTN': 75.39279,
#   'USDBYR': 19600,
#   'USDCDF': 2004.000119,
#   'USDCNY': 6.3684,
#   'USDCOP': 3932.5,
#   'USDCVE': 97.734464,
#   'USDDJF': 178.189827,
#   'USDDOP': 56.811746,
#   'USDEGP': 15.744101,
#   'USDETB': 48.619038,
#   'USDGHS': 6.180764,
#   'USDGMD': 52.55548,
#   'USDGNF': 9512.945285,
#   'USDGTQ': 7.750242,
#   'USDHNL': 24.17936,
#   'USDHTG': 100.66875,
#   'USDIDR': 14381.25,
#   'USDILS': 3.15785,
#   'USDINR': 75.418003,
#   'USDIQD': 1460.340533,
#   'USDIRR': 42274.999981,
#   'USDJOD': 0.709199,
#   'USDJPY': 113.722977,
#   'USDKES': 112.749978,
#   'USDKGS': 84.794203,
#   'USDKHR': 4077.732722,
# ...

# %%
conversion_rates = response.json()

# %%
conversion_rates = conversion_rates['quotes']

# %%
len(conversion_rates), len(currencies)
# Out:
# (73, 73)

# %%
# Making a dictionary of the conversion rates

# %%
dic_values = []
for x in conversion_rates.keys():
    dic_values.append(conversion_rates[x])

# %%
len(dic_values)
# Out:
# 73

# %%
conversion_rates_dict = dict(zip(currencies,dic_values))

# %%
#SSP will be added as 1 USD = 130.26 SSP

# %%
conversion_rates_dict['SSP'] = 130.26

# %%
# Adding a new column to our data with the conversion rates

# %%
price_2020_df['conv_rate'] = list(map(lambda x: conversion_rates_dict[x] , price_2020_df['cur_name']))
# Out:
# /var/folders/ld/8g4lbtw14x12q9rxlrk7ccx00000gn/T/ipykernel_4208/4267227431.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_2020_df['conv_rate'] = list(map(lambda x: conversion_rates_dict[x] , price_2020_df['cur_name']))

# %%
price_2020_df['conv_rate'].nunique()
# Out:
# 73

# %%
# Adding a new column to our data with the price in USD

# %%
price_2020_df["usd_rate"] = price_2020_df["mp_price"] / price_2020_df["conv_rate"]
# Out:
# /var/folders/ld/8g4lbtw14x12q9rxlrk7ccx00000gn/T/ipykernel_4208/1950825033.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_2020_df["usd_rate"] = price_2020_df["mp_price"] / price_2020_df["conv_rate"]

# %%
price_2020_df
# Out:
#          adm0_id    adm0_name  adm1_id   adm1_name  mkt_id  mkt_name  cm_id  \
# 69           1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 70           1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 71           1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 72           1.0  Afghanistan      272  Badakhshan     266  Fayzabad     55
# 275          1.0  Afghanistan      272  Badakhshan     266  Fayzabad     84
# ...          ...          ...      ...         ...     ...       ...    ...
# 1556443    270.0       Zambia     3434     Western    1462    Kalabo    265
# 1556444    270.0       Zambia     3434     Western    1462    Kalabo    265
# 1556445    270.0       Zambia     3434     Western    1462    Kalabo    265
# 1556446    270.0       Zambia     3434     Western    1462    Kalabo    265
# 1556447    270.0       Zambia     3434     Western    1462    Kalabo    265
#
# ...

# %%
price_2020_df.shape
# Out:
# (165098, 19)

# %%
price_2020_df['mp_month'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])
